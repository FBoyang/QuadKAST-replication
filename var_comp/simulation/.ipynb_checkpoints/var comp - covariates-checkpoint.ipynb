# %%
import numpy as np

import pandas as pd
import pickle

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
parameters = {
    'vary_N': [(5000, 25, 0.01), (10000, 25, 0.01), (50000, 25, 0.01), (-1, 25, 0.01)], # -1 means the uksize
    'vary_M': [(-1, 5, 0.01), (-1, 10, 0.01), (-1, 25, 0.01), (-1, 50, 0.01), (-1, 100, 0.01)],
    'vary_h2': [(-1, 25, 0.001), (-1, 25, 0.005), (-1, 25, 0.01), (-1, 25, 0.05), (-1, 25, 0.1)], # control everyting else to be constant
    'vary_genes': [(-1, -1, 0.001), (-1, -1, 0.005), (-1, -1, 0.01), (-1, -1, 0.05), (-1, -1, 0.1)], # since M vary, so want to be more realistict
}

# savePath="/home/boyang1995/research/QuadKAST/results/simulation/UKBB/"
savePath="/home/boyang1995/research/QuadKAST/results/simulation/UKBB/results_self_inter_incld/"
# savePath="/home/boyang1995/research/QuadKAST/results/simulation/UKBB/results_self_inter_excld/"
# params = pd.read_csv(f'{savePath}params.txt',sep=' ')

# %% [markdown]
# ### Simulation

# %%
results = []
Task='sumstas'

savePath = "/home/boyang1995/research/QuadKAST/results/simulation/synthetic/covar/"
params = "params.txt"


params = pd.read_csv(f'{savePath}{params}',sep=' ')

# params=parameters[Task]
for i in range(len(params)):
    for seed in range(1):
        N,M,D,sigma_g,sigma_e=params.iloc[i]
        N = int(N)
        M = int(M)
        D = int((M*(M-1))/2)
        try:
            with open(f'{savePath}{Task}_{N}_{M}_{D}_{sigma_g}_{sigma_e}', 'rb') as handle:
                all_results=pickle.load(handle)
            for elem in all_results:
                results.append([N,M,sigma_g,elem['varcomp'][0]])
        except:
            print(f'Missing: {Task}_{N}_{M}_{D}_{sigma_g}_{sigma_e}')
results_df = pd.DataFrame(data=results,columns=['N','M','h2','h2_est'])
results_df['h2_diff']=results_df['h2']-results_df['h2_est']

box_data = []
plt.figure(figsize=(10,6),dpi=200)
sns.boxplot(x="h2", y="h2_diff", data=results_df)
left, right = plt.xlim()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('$\sigma^2_{quad}$',fontsize=25)
plt.ylabel('$\sigma^2_{quad} - \hat{\sigma}^2_{quad}$',fontsize=25)
plt.hlines(0,left,right,linestyle='--',color='r')
# plt.legend(f'M={M}',fontsize=20)
# plt.title(f'h2={h2}',fontsize=25)
plt.show()

# %%
results = []
Task='sumstas'

savePath = "/home/boyang1995/research/QuadKAST/results/simulation/synthetic/covar/"
params = "params.txt"


params = pd.read_csv(f'{savePath}{params}',sep=' ')

# params=parameters[Task]
for i in range(len(params)):
    for seed in range(1):
        N,M,D,sigma_g,sigma_e=params.iloc[i]
        N = int(N)
        M = int(M)
        D = int((M*(M-1))/2)
        try:
            with open(f'{savePath}{Task}_{N}_{M}_{D}_{sigma_g}_{sigma_e}', 'rb') as handle:
                all_results=pickle.load(handle)
            for elem in all_results:
                results.append([N,M,sigma_g,elem['varcomp'][0]])
        except:
            print(f'Missing: {Task}_{N}_{M}_{D}_{sigma_g}_{sigma_e}')
results_df = pd.DataFrame(data=results,columns=['N','M','h2','h2_est'])
results_df['h2_ratio']=(results_df['h2']-results_df['h2_est'])/results_df['h2']

box_data = []
plt.figure(figsize=(10,6),dpi=200)
sns.boxplot(x="h2", y="h2_ratio", data=results_df)
left, right = plt.xlim()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('$\sigma^2_{quad}$',fontsize=25)
plt.ylabel('$(\sigma^2_{quad} - \hat{\sigma}^2_{quad})/\sigma^2_{quad}$',fontsize=25)
plt.hlines(0,left,right,linestyle='--',color='r')
# plt.legend(f'M={M}',fontsize=20)
# plt.title(f'h2={h2}',fontsize=25)
plt.show()

# %%
results_df[(results_df.h2==0.1)&(results_df.N==50000)]
# Out:
#          N   M   h2    h2_est  h2_ratio
# 800  50000  30  0.1  0.090478  0.095220
# 801  50000  30  0.1  0.109468 -0.094679
# 802  50000  30  0.1  0.084502  0.154976
# 803  50000  30  0.1  0.101037 -0.010375
# 804  50000  30  0.1  0.098190  0.018100
# ..     ...  ..  ...       ...       ...
# 895  50000  30  0.1  0.098767  0.012330
# 896  50000  30  0.1  0.110213 -0.102135
# 897  50000  30  0.1  0.096930  0.030701
# 898  50000  30  0.1  0.093936  0.060643
# 899  50000  30  0.1  0.100703 -0.007030
#
# [100 rows x 5 columns]

# %% [markdown]
# ### vary h2 relative error

# %%
results = []
Task='vary_h2'

params=parameters[Task]
for i in range(len(params)):
    for seed in range(1,3):
        N,M,sigma_g=params[i]
        N = int(N)
        M = int(M)
        try:
            with open(f'{savePath}{Task}_{N}_{M}_{sigma_g}_{seed}.pkl', 'rb') as handle:
                all_results=pickle.load(handle)
            for elem in all_results:
                results.append([N,M,sigma_g,elem['varcomp'][0]])
        except:
            print(f'Missing: {Task}_{N}_{M}_{sigma_g}_{seed}.pkl')
results_df = pd.DataFrame(data=results,columns=['N','M','h2','h2_est'])
results_df['h2_diff']=(results_df['h2']-results_df['h2_est'])/results_df['h2']

box_data = []
plt.figure(figsize=(10,6),dpi=200)
sns.boxplot(x="h2", y="h2_diff", data=results_df)
left, right = plt.xlim()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('$\sigma^2_{quad}$',fontsize=25)
plt.ylabel('$\\frac{\sigma^2_{quad} - \hat{\sigma}^2_{quad}}{\sigma^2_{quad}}$',fontsize=25)
plt.hlines(0,left,right,linestyle='--',color='r')
# plt.legend(f'M={M}',fontsize=20)
# plt.title(f'h2={h2}',fontsize=25)
plt.show()
# Out:
# Missing: vary_h2_-1_25_0.001_1.pkl
# Missing: vary_h2_-1_25_0.001_2.pkl
# Missing: vary_h2_-1_25_0.005_1.pkl
# Missing: vary_h2_-1_25_0.005_2.pkl
# Missing: vary_h2_-1_25_0.01_1.pkl
# Missing: vary_h2_-1_25_0.01_2.pkl
# Missing: vary_h2_-1_25_0.05_1.pkl
# Missing: vary_h2_-1_25_0.05_2.pkl
# Missing: vary_h2_-1_25_0.1_1.pkl
# Missing: vary_h2_-1_25_0.1_2.pkl

# %% [markdown]
# ### Vary genes

# %%
results = []
Task='vary_genes'

params=parameters[Task]
for i in range(len(params)):
    for seed in range(1,3):
        N,M,sigma_g=params[i]
        N = int(N)
        M = int(M)
        try:
            with open(f'{savePath}{Task}_{N}_{M}_{sigma_g}_{seed}.pkl', 'rb') as handle:
                all_results=pickle.load(handle)
            for elem in all_results:
                results.append([N,M,sigma_g,elem['varcomp'][0]])
        except:
            print(f'Missing: {Task}_{N}_{M}_{sigma_g}_{seed}.pkl')
results_df = pd.DataFrame(data=results,columns=['N','M','h2','h2_est'])
# results_df = results_df[results_df.h2<=0.01]
results_df['h2_diff']=results_df['h2']-results_df['h2_est']



box_data = []
plt.figure(figsize=(10,6),dpi=200)
sns.boxplot(x="h2", y="h2_diff", data=results_df)
left, right = plt.xlim()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('$\sigma_{quad}^2$',fontsize=25)
plt.ylabel('$\sigma_{quad}^2-\hat{\sigma}_{quad}^2$',fontsize=25)
plt.hlines(0,left,right,linestyle='--',color='r')
# plt.legend(f'M={M}',fontsize=20)
# plt.title(f'h2={h2}',fontsize=25)
plt.show()
# Out:
# Missing: vary_genes_-1_-1_0.001_1.pkl
# Missing: vary_genes_-1_-1_0.001_2.pkl
# Missing: vary_genes_-1_-1_0.005_1.pkl
# Missing: vary_genes_-1_-1_0.005_2.pkl
# Missing: vary_genes_-1_-1_0.01_1.pkl
# Missing: vary_genes_-1_-1_0.01_2.pkl
# Missing: vary_genes_-1_-1_0.05_1.pkl
# Missing: vary_genes_-1_-1_0.05_2.pkl
# Missing: vary_genes_-1_-1_0.1_1.pkl
# Missing: vary_genes_-1_-1_0.1_2.pkl

# %% [markdown]
# ### Vary genes relative error

# %%
results = []
Task='vary_genes'

params=parameters[Task]
for i in range(len(params)):
    for seed in range(1,3):
        N,M,sigma_g=params[i]
        N = int(N)
        M = int(M)
        try:
            with open(f'{savePath}{Task}_{N}_{M}_{sigma_g}_{seed}.pkl', 'rb') as handle:
                all_results=pickle.load(handle)
            for elem in all_results:
                results.append([N,M,sigma_g,elem['varcomp'][0]])
        except:
            print(f'Missing: {Task}_{N}_{M}_{sigma_g}_{seed}.pkl')
results_df = pd.DataFrame(data=results,columns=['N','M','h2','h2_est'])
# results_df = results_df[results_df.h2<=0.01]
results_df['h2_diff']=(results_df['h2']-results_df['h2_est'])/results_df['h2']



box_data = []
plt.figure(figsize=(10,6),dpi=200)
sns.boxplot(x="h2", y="h2_diff", data=results_df)
left, right = plt.xlim()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('$\sigma_{quad}^2$',fontsize=25)
plt.ylabel('$\\frac{\sigma^2_{quad} - \hat{\sigma}^2_{quad}}{\sigma^2_{quad}}$',fontsize=25)
plt.hlines(0,left,right,linestyle='--',color='r')
# plt.legend(f'M={M}',fontsize=20)
# plt.title(f'h2={h2}',fontsize=25)
plt.show()
# Out:
# Missing: vary_genes_-1_-1_0.001_1.pkl
# Missing: vary_genes_-1_-1_0.001_2.pkl
# Missing: vary_genes_-1_-1_0.005_1.pkl
# Missing: vary_genes_-1_-1_0.005_2.pkl
# Missing: vary_genes_-1_-1_0.01_1.pkl
# Missing: vary_genes_-1_-1_0.01_2.pkl
# Missing: vary_genes_-1_-1_0.05_1.pkl
# Missing: vary_genes_-1_-1_0.05_2.pkl
# Missing: vary_genes_-1_-1_0.1_1.pkl
# Missing: vary_genes_-1_-1_0.1_2.pkl

# %%
results_df
# Out:
#          N   M     D    h2    h2_est
# 0     5000  30  10.0  0.10  0.105476
# 1     5000  30  10.0  0.10  0.095495
# 2     5000  30  10.0  0.10  0.095863
# 3     5000  30  10.0  0.10  0.097401
# 4     5000  30  10.0  0.10  0.096548
# ...    ...  ..   ...   ...       ...
# 1195  5000  30  50.0  0.01  0.010398
# 1196  5000  30  50.0  0.01  0.010570
# 1197  5000  30  50.0  0.01  0.011595
# 1198  5000  30  50.0  0.01  0.011202
# 1199  5000  30  50.0  0.01  0.010355
#
# [1200 rows x 5 columns]

# %%
N = 5000
D = 50
M = 30
h2=0.1
results_sdf = results_df[(results_df.D==D)&(results_df.N==N)&(results_df.h2==h2)]
# results_sdf['h2_diff']=results_sdf['h2_est']-results_sdf['h2']
plt.figure(figsize=(10,6),dpi=200)
sns.boxplot(x="M", y="h2_est", hue="N", data=results_sdf)
left, right = plt.xlim()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('M',fontsize=25)
plt.ylabel('$\hat{h}^2$',fontsize=25)
plt.hlines(h2,left,right,linestyle='--',color='r')
plt.legend(fontsize=20)
# plt.title(f'h2={h2}',fontsize=25)
plt.show()

# %%
results_df['h2_diff']
# Out:
# 0     -0.000056
# 1     -0.000046
# 2     -0.000017
# 3     -0.000098
# 4     -0.000057
#          ...
# 495    0.013951
# 496   -0.009738
# 497   -0.003190
# 498    0.005352
# 499    0.000867
# Name: h2_diff, Length: 500, dtype: float64
